# %% [markdown]
# # Towards scalabe submerged acuatic vegetation mapping using Sentinel-2

# %% [markdown]
# ## Intro

# %% [markdown]
# Submerged aquatic vegetation (SAV) in shallow waters can, to some extent, be mapped using satellite imagery because seafloor components interact with light in distinct, wavelength-dependent ways. Seagrass, algae, and sediments generate characteristic optical responses related to their pigments, structure, and composition. When the water column is sufficiently shallow and clear to allow light to reach the bottom and return to the surface, these spectral differences can be detected by satellite sensors, enabling underwater vegetation to be distinguished from other benthic covers.

# %% [markdown]
# Sentinel-2 Level-2A products provide valuable information for studying the ecology of coastal seafloor habitats. In particular, Bands 1 to 4, which have the greatest penetration in the water column, can be used to infer the presence of submerged aquatic vegetation (SAV) when waters are sufficiently clear and shallow to allow reliable retrieval of bottom reflectance. However, determining whether the spectral signatures of different SAV types are sufficiently distinct, as observed by the MSI sensor onboard the Sentinel-2 satellites, and not excessively attenuated by the water column to enable discrimination among vegetation types, remains a challenge. Addressing this limitation requires high-quality in situ reference data to properly characterize benthic optical properties and evaluate the separability of SAV types.

# %% [markdown]
# In this notebook, we explore the potential of the Copernicus Data Space Ecosistem (CDSE), together with [extensive field data collected by the Seagrass Ecology Group](https://coastal-ai.github.io/GEAM_GEODATABASE/) of the Spanish Institute of Oceanography (IEO-CSIC)  to overcome this limitation and map SAV in the Tabarca Marine Reserve, a coastal protected area in the Spanish Mediterranean.

# %% [markdown]
# ## Fetching S2 L2A zarr data

# %% [markdown]
# ### Libraries

# %%
import os
import dask
import xarray as xr
from xcube.core.store import new_data_store
from xcube.util.config import load_configs
from xcube.webapi.viewer import Viewer
from xcube_resampling.utils import reproject_bbox
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pystac_client
from pystac_client import CollectionSearch
from matplotlib.gridspec import GridSpec
import geopandas as gpd
from shapely.geometry import box
import folium

# %% [markdown]
# ### Test region

# %%
bbox = [-5.44,43.48,-5.36,43.54]
crs_wgs84 = "EPSG:4326"
crs_utm = "EPSG:32631"
bbox_utm = reproject_bbox(bbox, "EPSG:4326", crs_utm)
time_range = ["2024-01-01", None]

# Center of the bbox
center_lat = (bbox[1] + bbox[3]) / 2
center_lon = (bbox[0] + bbox[2]) / 2

# Create folium map
m = folium.Map(location=[center_lat, center_lon], zoom_start=12, tiles="CartoDB positron")

# Add bbox as a rectangle
folium.Rectangle(
    bounds=[[bbox[1], bbox[0]], [bbox[3], bbox[2]]],
    color="red",
    fill=False,
    weight=2,
    tooltip="AOI"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a1c7a27c442fd3397b92cf6d45be78b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a1c7a27c442fd3397b92cf6d45be78b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a1c7a27c442fd3397b92cf6d45be78b = L.map(
#                 &quot;map_0a1c7a27c442fd3397b92cf6d45be78b&quot;,
#                 {
#                     center: [43.51, -5.4],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d18fcbb4791f423e134ad5e2c5794069 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d18fcbb4791f423e134ad5e2c5794069.addTo(map_0a1c7a27c442fd3397b92cf6d45be78b);
#
#
#             var rectangle_60839619a1061b398cb3e76074e3d803 = L.rectangle(
#                 [[43.48, -5.44], [43.54, -5.36]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0a1c7a27c442fd3397b92cf6d45be78b);
#
#
#             rectangle_60839619a1061b398cb3e76074e3d803.bindTooltip(
#                 `&lt;div&gt;
#                      AOI
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### pystac API search

# %%
catalog = pystac_client.Client.open("https://stac.core.eopf.eodc.eu")
# Search with cloud cover filter
items = list(
    catalog.search(
        collections=["sentinel-2-l2a"],
        bbox=bbox,
        datetime=time_range,
        query={"eo:cloud_cover": {"lt": 50}},  # Cloud cover less than 20%
    ).items()
)
print(len(items))
# Out:
# 95

# %%
item = items[5]  # extracting the first item

ds = xr.open_dataset(
    item.assets["product"].href,
    **item.assets["product"].extra_fields["xarray:open_datatree_kwargs"],
)  # The engine="eopf-zarr" is already embedded in the STAC metadata

ds.quality_l2a_quicklook_r60m_tci.plot.imshow(rgb="quality_l2a_quicklook_r60m_band")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions as exc:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:469, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     468     if ex:
# --> 469         raise ex
#     470 if (
#     471     len(paths) > 1
#     472     or isinstance(path, list)
#     473     or paths[0] != self._strip_protocol(path)
#     474 ):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:244, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     243 try:
# --> 244     return await asyncio.wait_for(coro, timeout=timeout), i
#     245 except Exception as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:247, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     246     out = await r.read()
# --> 247     self._raise_not_found_for_status(r, url)
#     248 return out
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:229, in HTTPFileSystem._raise_not_found_for_status(self, response, url)
#     228 if response.status == 404:
# --> 229     raise FileNotFoundError(url)
#     230 response.raise_for_status()
#
# FileNotFoundError: https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202512-s02msil2a-eu/11/products/cpm_v262/S2B_MSIL2A_20251211T111349_N0511_R137_T30TUP_20251212T112638.zarr/.zmetadata
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:159, in FSMap.__getitem__(self, key, default)
#     158         return default
# --> 159     raise KeyError(key) from exc
#     160 return result
#
# KeyError: '.zmetadata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1761, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1760 try:
# -> 1761     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#    1762 except (ValueError, KeyError):
#    1763     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/convenience.py:1362, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1361 # setup metadata store
# -> 1362 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1364 # pass through
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:3045, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3044 # retrieve consolidated metadata
# -> 3045 meta = json_loads(self.store[metadata_key])
#    3047 # check format of consolidated metadata
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1448, in FSStore.__getitem__(self, key)
#    1447 except self.exceptions as e:
# -> 1448     raise KeyError(key) from e
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1765, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1764 try:
# -> 1765     zarr_group = zarr.open_group(store, **open_kwargs)
#    1766     emit_user_level_warning(
#    1767         "Failed to open Zarr store with consolidated metadata, "
#    1768         "but successfully read with non-consolidated metadata. "
#    (...)
#    1778         RuntimeWarning,
#    1779     )
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 item = items[5]  # extracting the first item
# ----> 3 ds = xr.open_dataset(
#       4     item.assets["product"].href,
#       5     **item.assets["product"].extra_fields["xarray:open_datatree_kwargs"],
#       6 )  # The engine="eopf-zarr" is already embedded in the STAC metadata
#       8 ds.quality_l2a_quicklook_r60m_tci.plot.imshow(rgb="quality_l2a_quicklook_r60m_band")
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:679, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     667 decoders = _resolve_decoders_kwargs(
#     668     decode_cf,
#     669     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     675     decode_coords=decode_coords,
#     676 )
#     678 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 679 backend_ds = backend.open_dataset(
#     680     filename_or_obj,
#     681     drop_variables=drop_variables,
#     682     **decoders,
#     683     **kwargs,
#     684 )
#     685 ds = _dataset_from_backend_dataset(
#     686     backend_ds,
#     687     filename_or_obj,
#    (...)
#     697     **kwargs,
#     698 )
#     699 return ds
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:196, in EopfBackend.open_dataset(self, filename_or_obj, op_mode, storage_options, group_sep, variables, product_type, resolution, bbox, crs, interp_methods, agg_methods, drop_variables, decode_timedelta)
#     192 xr.set_options(display_expand_attrs=False)
#     194 assert_arg_is_one_of(op_mode, "op_mode", OP_MODES)
# --> 196 datatree = self.open_datatree(
#     197     filename_or_obj,
#     198     op_mode="native",
#     199     storage_options=storage_options,
#     200     # here as it is required for all backends
#     201     drop_variables=drop_variables,
#     202     # here to silence xarray warnings
#     203     decode_timedelta=decode_timedelta,
#     204 )
#     206 _assert_datatree_is_chunked(datatree)
#     208 if op_mode == OP_MODE_NATIVE:
#     209     # native mode
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:84, in EopfBackend.open_datatree(self, filename_or_obj, op_mode, product_type, storage_options, drop_variables, decode_timedelta)
#      81 source = normalize_source(filename_or_obj, storage_options)
#      83 # noinspection PyTypeChecker
# ---> 84 datatree = xr.open_datatree(
#      85     source,
#      86     engine="zarr",
#      87     group=subgroup_path,
#      88     # prefer the chunking from the Zarr metadata
#      89     chunks={},
#      90     # here as it is required for all backends
#      91     drop_variables=drop_variables,
#      92     # here to silence xarray warnings
#      93     decode_timedelta=decode_timedelta,
#      94 )
#      96 _assert_datatree_is_chunked(datatree)
#      98 if op_mode == OP_MODE_NATIVE:
#      99     # native mode, so we return tree as-is
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:1113, in open_datatree(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#    1101 decoders = _resolve_decoders_kwargs(
#    1102     decode_cf,
#    1103     open_backend_dataset_parameters=(),
#    (...)
#    1109     decode_coords=decode_coords,
#    1110 )
#    1111 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# -> 1113 backend_tree = backend.open_datatree(
#    1114     filename_or_obj,
#    1115     drop_variables=drop_variables,
#    1116     **decoders,
#    1117     **kwargs,
#    1118 )
#    1120 tree = _datatree_from_backend_datatree(
#    1121     backend_tree,
#    1122     filename_or_obj,
#    (...)
#    1132     **kwargs,
#    1133 )
#    1135 return tree
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1614, in ZarrBackendEntrypoint.open_datatree(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1593 def open_datatree(
#    1594     self,
#    1595     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#    1611     zarr_format=None,
#    1612 ) -> DataTree:
#    1613     filename_or_obj = _normalize_path(filename_or_obj)
# -> 1614     groups_dict = self.open_groups_as_dict(
#    1615         filename_or_obj=filename_or_obj,
#    1616         mask_and_scale=mask_and_scale,
#    1617         decode_times=decode_times,
#    1618         concat_characters=concat_characters,
#    1619         decode_coords=decode_coords,
#    1620         drop_variables=drop_variables,
#    1621         use_cftime=use_cftime,
#    1622         decode_timedelta=decode_timedelta,
#    1623         group=group,
#    1624         mode=mode,
#    1625         synchronizer=synchronizer,
#    1626         consolidated=consolidated,
#    1627         chunk_store=chunk_store,
#    1628         storage_options=storage_options,
#    1629         zarr_version=zarr_version,
#    1630         zarr_format=zarr_format,
#    1631     )
#    1633     return datatree_from_dict_with_io_cleanup(groups_dict)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1665, in ZarrBackendEntrypoint.open_groups_as_dict(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1662 else:
#    1663     parent = str(NodePath("/"))
# -> 1665 stores = ZarrStore.open_store(
#    1666     filename_or_obj,
#    1667     group=parent,
#    1668     mode=mode,
#    1669     synchronizer=synchronizer,
#    1670     consolidated=consolidated,
#    1671     consolidate_on_close=False,
#    1672     chunk_store=chunk_store,
#    1673     storage_options=storage_options,
#    1674     zarr_version=zarr_version,
#    1675     zarr_format=zarr_format,
#    1676 )
#    1678 groups_dict = {}
#    1680 for path_group, store in stores.items():
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:648, in ZarrStore.open_store(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     623 @classmethod
#     624 def open_store(
#     625     cls,
#    (...)
#     641     cache_members: bool = True,
#     642 ):
#     643     (
#     644         zarr_group,
#     645         consolidate_on_close,
#     646         close_store_on_close,
#     647         use_zarr_fill_value_as_mask,
# --> 648     ) = _get_open_params(
#     649         store=store,
#     650         mode=mode,
#     651         synchronizer=synchronizer,
#     652         group=group,
#     653         consolidated=consolidated,
#     654         consolidate_on_close=consolidate_on_close,
#     655         chunk_store=chunk_store,
#     656         storage_options=storage_options,
#     657         zarr_version=zarr_version,
#     658         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     659         zarr_format=zarr_format,
#     660     )
#     661     group_paths = list(_iter_zarr_groups(zarr_group, parent=group))
#     662     return {
#     663         group: cls(
#     664             zarr_group.get(group),
#    (...)
#     675         for group in group_paths
#     676     }
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1781, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1766             emit_user_level_warning(
#    1767                 "Failed to open Zarr store with consolidated metadata, "
#    1768                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1778                 RuntimeWarning,
#    1779             )
#    1780         except missing_exc as err:
# -> 1781             raise FileNotFoundError(
#    1782                 f"No such file or directory: '{store}'"
#    1783             ) from err
#    1784 elif consolidated:
#    1785     # TODO: an option to pass the metadata_key keyword
#    1786     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#
# FileNotFoundError: No such file or directory: 'https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202512-s02msil2a-eu/11/products/cpm_v262/S2B_MSIL2A_20251211T111349_N0511_R137_T30TUP_20251212T112638.zarr'

# %% [markdown]
# ### xcube

# %%
xr.set_options(display_expand_attrs=False)
store = new_data_store("eopf-zarr")
store.list_data_ids()
# Out:
# ['sentinel-2-l1c',
#  'sentinel-2-l2a',
#  'sentinel-3-olci-l1-efr',
#  'sentinel-3-olci-l2-lfr',
#  'sentinel-3-slstr-l1-rbt',
#  'sentinel-3-slstr-l2-lst']

# %%
# %%time
ds = store.open_data(
    data_id="sentinel-2-l2a",
    bbox=bbox_utm, # bbox in degrees can also be used
    time_range=time_range,
    spatial_res=10, # in that case convert m to degrees: 10 / 111320 
    crs=crs_utm, # and change to EPSG:4326
    variables=["b01", "b02", "b03", "b04", "scl"],
)
ds
# Out:
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T30TUP_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251104T112139_N0511_R037_T29TQJ_20251104T134759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T30TUP_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20251101T112241_N0511_R037_T29TQJ_20251101T151319' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T30TUP_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20251101T111119_N0511_R137_T29TQJ_20251101T135730' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250930T112131_N0511_R037_T30TUP_20250930T150514' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250930T112131_N0511_R037_T29TQJ_20250930T150514' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250922T110659_N0511_R137_T30TUP_20250923T075628' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250920T112131_N0511_R037_T30TUP_20250920T144717' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250920T112131_N0511_R037_T29TQJ_20250920T144717' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250919T110741_N0511_R137_T30TUP_20250919T152715' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250919T110741_N0511_R137_T29TQJ_20250919T152715' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250917T110731_N0511_R137_T30TUP_20250917T163216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250917T110731_N0511_R137_T29TQJ_20250917T163216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250915T112109_N0511_R037_T30TUP_20250915T140014' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250915T112109_N0511_R037_T29TQJ_20250915T140014' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250912T112131_N0511_R037_T30TUP_20250912T164010' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250912T112131_N0511_R037_T29TQJ_20250912T164010' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250912T110619_N0511_R137_T30TUP_20250912T133026' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250912T110619_N0511_R137_T29TQJ_20250912T133026' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250910T112131_N0511_R037_T30TUP_20250910T144759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250910T112131_N0511_R037_T29TQJ_20250910T144759' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250909T110651_N0511_R137_T30TUP_20250909T151313' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250909T110651_N0511_R137_T29TQJ_20250909T151313' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250907T110631_N0511_R137_T30TUP_20250907T150514' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250907T110631_N0511_R137_T29TQJ_20250907T150514' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250905T112109_N0511_R037_T30TUP_20250905T133452' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250905T112109_N0511_R037_T29TQJ_20250905T133452' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250902T112131_N0511_R037_T30TUP_20250902T161719' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250902T112131_N0511_R037_T29TQJ_20250902T161719' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250902T110619_N0511_R137_T30TUP_20250902T135238' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250902T110619_N0511_R137_T29TQJ_20250902T135238' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250831T112131_N0511_R037_T30TUP_20250831T154413' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250831T112131_N0511_R037_T29TQJ_20250831T154413' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250830T110701_N0511_R137_T30TUP_20250830T152014' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250830T110701_N0511_R137_T29TQJ_20250830T152014' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250828T110641_N0511_R137_T30TUP_20250828T151013' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250828T110641_N0511_R137_T29TQJ_20250828T151013' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250823T112131_N0511_R037_T30TUP_20250823T162957' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250823T112131_N0511_R037_T29TQJ_20250823T162957' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250823T110619_N0511_R137_T30TUP_20250823T134914' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250823T110619_N0511_R137_T29TQJ_20250823T134914' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250821T112131_N0511_R037_T30TUP_20250821T150517' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250821T112131_N0511_R037_T29TQJ_20250821T150517' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250818T110641_N0511_R137_T30TUP_20250818T163305' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250818T110641_N0511_R137_T29TQJ_20250818T163305' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250816T112119_N0511_R037_T29TQJ_20250816T122832' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250813T112131_N0511_R037_T30TUP_20250813T160722' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250813T112131_N0511_R037_T29TQJ_20250813T160722' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250813T110619_N0511_R137_T29TQJ_20250813T133147' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250811T112131_N0511_R037_T30TUP_20250811T152216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250811T112131_N0511_R037_T29TQJ_20250811T152216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250810T110701_N0511_R137_T30TUP_20250810T151608' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250810T110701_N0511_R137_T29TQJ_20250810T151608' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250808T110641_N0511_R137_T30TUP_20250808T144618' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250808T110641_N0511_R137_T29TQJ_20250808T144618' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250806T112119_N0511_R037_T30TUP_20250806T140603' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250806T112119_N0511_R037_T29TQJ_20250806T140603' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250803T110619_N0511_R137_T30TUP_20250803T135458' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250803T110619_N0511_R137_T29TQJ_20250803T135458' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250712T112141_N0511_R037_T30TUP_20250712T145514' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250711T110651_N0511_R137_T30TUP_20250711T153113' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250711T110651_N0511_R137_T29TQJ_20250711T153113' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250707T112119_N0511_R037_T30TUP_20250707T133709' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250707T112119_N0511_R037_T29TQJ_20250707T133709' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250704T112131_N0511_R037_T30TUP_20250704T162920' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250704T112131_N0511_R037_T29TQJ_20250704T162920' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250704T110619_N0511_R137_T30TUP_20250704T135147' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250704T110619_N0511_R137_T29TQJ_20250704T135147' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250702T112141_N0511_R037_T30TUP_20250702T144903' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250702T112141_N0511_R037_T29TQJ_20250702T144903' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250701T110711_N0511_R137_T30TUP_20250701T153201' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250701T110711_N0511_R137_T29TQJ_20250701T153201' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250629T110641_N0511_R137_T30TUP_20250629T150216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250629T110641_N0511_R137_T29TQJ_20250629T150216' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250627T112119_N0511_R037_T30TUP_20250627T133415' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250627T112119_N0511_R037_T29TQJ_20250627T133415' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250624T112131_N0511_R037_T30TUP_20250624T162916' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250624T112131_N0511_R037_T29TQJ_20250624T162916' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250624T110619_N0511_R137_T30TUP_20250624T140140' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250624T110619_N0511_R137_T29TQJ_20250624T140140' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250622T112131_N0511_R037_T30TUP_20250622T135816' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250622T112131_N0511_R037_T29TQJ_20250622T135816' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250621T110651_N0511_R137_T30TUP_20250621T150616' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250621T110651_N0511_R137_T29TQJ_20250621T150616' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250619T110641_N0511_R137_T30TUP_20250619T151116' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250619T110641_N0511_R137_T29TQJ_20250619T151116' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250617T112109_N0511_R037_T30TUP_20250617T133829' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250617T112109_N0511_R037_T29TQJ_20250617T133829' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250614T112131_N0511_R037_T30TUP_20250614T161201' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250614T112131_N0511_R037_T29TQJ_20250614T161201' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250614T110619_N0511_R137_T30TUP_20250614T140230' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250614T110619_N0511_R137_T29TQJ_20250614T140230' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250612T112131_N0511_R037_T30TUP_20250612T150504' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250612T112131_N0511_R037_T29TQJ_20250612T150504' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250611T110711_N0511_R137_T30TUP_20250611T175017' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250611T110711_N0511_R137_T29TQJ_20250611T175017' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250609T110641_N0511_R137_T30TUP_20250609T162715' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250609T110641_N0511_R137_T29TQJ_20250609T162715' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250607T112109_N0511_R037_T30TUP_20250607T133245' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250607T112109_N0511_R037_T29TQJ_20250607T133245' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250604T112131_N0511_R037_T30TUP_20250604T162818' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250604T112131_N0511_R037_T29TQJ_20250604T162818' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250604T110619_N0511_R137_T30TUP_20250604T151549' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250604T110619_N0511_R137_T29TQJ_20250604T151549' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250602T112131_N0511_R037_T30TUP_20250602T144620' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2C_MSIL2A_20250602T112131_N0511_R037_T29TQJ_20250602T144620' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T30TUP_20250405T182117' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2A_MSIL2A_20250405T112131_N0511_R037_T29TQJ_20250405T182117' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T30TUP_20250405T140215' is deprecated.
#   warnings.warn(
# /Users/fer/anaconda3/envs/landscape/lib/python3.13/site-packages/pystac/item.py:481: DeprecatedWarning: The item 'S2B_MSIL2A_20250405T110619_N0511_R137_T29TQJ_20250405T140215' is deprecated.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions as exc:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:469, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     468     if ex:
# --> 469         raise ex
#     470 if (
#     471     len(paths) > 1
#     472     or isinstance(path, list)
#     473     or paths[0] != self._strip_protocol(path)
#     474 ):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:244, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     243 try:
# --> 244     return await asyncio.wait_for(coro, timeout=timeout), i
#     245 except Exception as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:247, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     246     out = await r.read()
# --> 247     self._raise_not_found_for_status(r, url)
#     248 return out
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:229, in HTTPFileSystem._raise_not_found_for_status(self, response, url)
#     228 if response.status == 404:
# --> 229     raise FileNotFoundError(url)
#     230 response.raise_for_status()
#
# FileNotFoundError: https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202509-s02msil2a-eu/25/products/cpm_v256/S2B_MSIL2A_20250925T112109_N0511_R037_T29TQJ_20250925T151904.zarr/.zmetadata
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/mapping.py:159, in FSMap.__getitem__(self, key, default)
#     158         return default
# --> 159     raise KeyError(key) from exc
#     160 return result
#
# KeyError: '.zmetadata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1761, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1760 try:
# -> 1761     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#    1762 except (ValueError, KeyError):
#    1763     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/convenience.py:1362, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1361 # setup metadata store
# -> 1362 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1364 # pass through
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:3045, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3044 # retrieve consolidated metadata
# -> 3045 meta = json_loads(self.store[metadata_key])
#    3047 # check format of consolidated metadata
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1448, in FSStore.__getitem__(self, key)
#    1447 except self.exceptions as e:
# -> 1448     raise KeyError(key) from e
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1765, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1764 try:
# -> 1765     zarr_group = zarr.open_group(store, **open_kwargs)
#    1766     emit_user_level_warning(
#    1767         "Failed to open Zarr store with consolidated metadata, "
#    1768         "but successfully read with non-consolidated metadata. "
#    (...)
#    1778         RuntimeWarning,
#    1779     )
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/store.py:123, in EOPFZarrDataStore.open_data(self, data_id, opener_id, data_type, **open_params)
#     120 if len(items) == 0:
#     121     raise DataStoreError(f"No items found for search_params {search_params}.")
# --> 123 return product_handler.open_data(items, **open_params)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:102, in Sen2ProductHandler.open_data(self, items, **open_params)
#      99 grouped_items = group_items(items)
#     101 # generate cube by mosaicking and stacking tiles
# --> 102 ds = generate_cube(grouped_items, **open_params)
#     104 # add attributes
#     105 ds = add_attributes(ds, grouped_items, **open_params)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:239, in generate_cube(grouped_items, **open_params)
#     237 list_ds_utm = []
#     238 for crs, tile_ids in utm_tile_id.items():
# --> 239     ds = _generate_utm_cube(grouped_items.sel(tile_id=tile_ids), crs, **open_params)
#     240     list_ds_utm.append(ds)
#     242 # Reproject datasets from different UTM zones to a common grid reference system
#     243 # and merge them into a single unified dataset for seamless spatial analysis.
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xcube_eopf/prodhandlers/sentinel2.py:290, in _generate_utm_cube(grouped_items, crs_utm, **open_params)
#     288 multi_tiles = []
#     289 for item in items:
# --> 290     ds = xr.open_dataset(
#     291         item.assets["product"].href,
#     292         engine="eopf-zarr",
#     293         chunks={},
#     294         **xarray_open_params,
#     295     )
#     296     ds = ds.sel(
#     297         x=slice(final_bbox[0], final_bbox[2]),
#     298         y=slice(final_bbox[3], final_bbox[1]),
#     299     )
#     300     if any(size == 0 for size in ds.sizes.values()):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:679, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     667 decoders = _resolve_decoders_kwargs(
#     668     decode_cf,
#     669     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     675     decode_coords=decode_coords,
#     676 )
#     678 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 679 backend_ds = backend.open_dataset(
#     680     filename_or_obj,
#     681     drop_variables=drop_variables,
#     682     **decoders,
#     683     **kwargs,
#     684 )
#     685 ds = _dataset_from_backend_dataset(
#     686     backend_ds,
#     687     filename_or_obj,
#    (...)
#     697     **kwargs,
#     698 )
#     699 return ds
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:196, in EopfBackend.open_dataset(self, filename_or_obj, op_mode, storage_options, group_sep, variables, product_type, resolution, bbox, crs, interp_methods, agg_methods, drop_variables, decode_timedelta)
#     192 xr.set_options(display_expand_attrs=False)
#     194 assert_arg_is_one_of(op_mode, "op_mode", OP_MODES)
# --> 196 datatree = self.open_datatree(
#     197     filename_or_obj,
#     198     op_mode="native",
#     199     storage_options=storage_options,
#     200     # here as it is required for all backends
#     201     drop_variables=drop_variables,
#     202     # here to silence xarray warnings
#     203     decode_timedelta=decode_timedelta,
#     204 )
#     206 _assert_datatree_is_chunked(datatree)
#     208 if op_mode == OP_MODE_NATIVE:
#     209     # native mode
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray_eopf/backend.py:84, in EopfBackend.open_datatree(self, filename_or_obj, op_mode, product_type, storage_options, drop_variables, decode_timedelta)
#      81 source = normalize_source(filename_or_obj, storage_options)
#      83 # noinspection PyTypeChecker
# ---> 84 datatree = xr.open_datatree(
#      85     source,
#      86     engine="zarr",
#      87     group=subgroup_path,
#      88     # prefer the chunking from the Zarr metadata
#      89     chunks={},
#      90     # here as it is required for all backends
#      91     drop_variables=drop_variables,
#      92     # here to silence xarray warnings
#      93     decode_timedelta=decode_timedelta,
#      94 )
#      96 _assert_datatree_is_chunked(datatree)
#      98 if op_mode == OP_MODE_NATIVE:
#      99     # native mode, so we return tree as-is
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/api.py:1113, in open_datatree(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#    1101 decoders = _resolve_decoders_kwargs(
#    1102     decode_cf,
#    1103     open_backend_dataset_parameters=(),
#    (...)
#    1109     decode_coords=decode_coords,
#    1110 )
#    1111 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# -> 1113 backend_tree = backend.open_datatree(
#    1114     filename_or_obj,
#    1115     drop_variables=drop_variables,
#    1116     **decoders,
#    1117     **kwargs,
#    1118 )
#    1120 tree = _datatree_from_backend_datatree(
#    1121     backend_tree,
#    1122     filename_or_obj,
#    (...)
#    1132     **kwargs,
#    1133 )
#    1135 return tree
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1614, in ZarrBackendEntrypoint.open_datatree(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1593 def open_datatree(
#    1594     self,
#    1595     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#    1611     zarr_format=None,
#    1612 ) -> DataTree:
#    1613     filename_or_obj = _normalize_path(filename_or_obj)
# -> 1614     groups_dict = self.open_groups_as_dict(
#    1615         filename_or_obj=filename_or_obj,
#    1616         mask_and_scale=mask_and_scale,
#    1617         decode_times=decode_times,
#    1618         concat_characters=concat_characters,
#    1619         decode_coords=decode_coords,
#    1620         drop_variables=drop_variables,
#    1621         use_cftime=use_cftime,
#    1622         decode_timedelta=decode_timedelta,
#    1623         group=group,
#    1624         mode=mode,
#    1625         synchronizer=synchronizer,
#    1626         consolidated=consolidated,
#    1627         chunk_store=chunk_store,
#    1628         storage_options=storage_options,
#    1629         zarr_version=zarr_version,
#    1630         zarr_format=zarr_format,
#    1631     )
#    1633     return datatree_from_dict_with_io_cleanup(groups_dict)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1665, in ZarrBackendEntrypoint.open_groups_as_dict(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format)
#    1662 else:
#    1663     parent = str(NodePath("/"))
# -> 1665 stores = ZarrStore.open_store(
#    1666     filename_or_obj,
#    1667     group=parent,
#    1668     mode=mode,
#    1669     synchronizer=synchronizer,
#    1670     consolidated=consolidated,
#    1671     consolidate_on_close=False,
#    1672     chunk_store=chunk_store,
#    1673     storage_options=storage_options,
#    1674     zarr_version=zarr_version,
#    1675     zarr_format=zarr_format,
#    1676 )
#    1678 groups_dict = {}
#    1680 for path_group, store in stores.items():
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:648, in ZarrStore.open_store(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     623 @classmethod
#     624 def open_store(
#     625     cls,
#    (...)
#     641     cache_members: bool = True,
#     642 ):
#     643     (
#     644         zarr_group,
#     645         consolidate_on_close,
#     646         close_store_on_close,
#     647         use_zarr_fill_value_as_mask,
# --> 648     ) = _get_open_params(
#     649         store=store,
#     650         mode=mode,
#     651         synchronizer=synchronizer,
#     652         group=group,
#     653         consolidated=consolidated,
#     654         consolidate_on_close=consolidate_on_close,
#     655         chunk_store=chunk_store,
#     656         storage_options=storage_options,
#     657         zarr_version=zarr_version,
#     658         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     659         zarr_format=zarr_format,
#     660     )
#     661     group_paths = list(_iter_zarr_groups(zarr_group, parent=group))
#     662     return {
#     663         group: cls(
#     664             zarr_group.get(group),
#    (...)
#     675         for group in group_paths
#     676     }
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:1781, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1766             emit_user_level_warning(
#    1767                 "Failed to open Zarr store with consolidated metadata, "
#    1768                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1778                 RuntimeWarning,
#    1779             )
#    1780         except missing_exc as err:
# -> 1781             raise FileNotFoundError(
#    1782                 f"No such file or directory: '{store}'"
#    1783             ) from err
#    1784 elif consolidated:
#    1785     # TODO: an option to pass the metadata_key keyword
#    1786     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#
# FileNotFoundError: No such file or directory: 'https://objects.eodc.eu:443/e05ab01a9d56408d82ac32d69a5aae2a:202509-s02msil2a-eu/25/products/cpm_v256/S2B_MSIL2A_20250925T112109_N0511_R037_T29TQJ_20250925T151904.zarr'

# %%
# %%time
ds.b02.isel(time=3).plot(vmin=0, vmax=0.2)
# Out:
# CPU times: user 8.58 s, sys: 1.57 s, total: 10.2 s
# Wall time: 27.7 s

# %% [markdown]
# ### xcube viewer

# %%
#if running in jupyter lab
#os.environ["XCUBE_JUPYTER_LAB_URL"] = ( "https://jupyterhub.user.eopf.eodc.eu/user/f.garcia@ieo.csic.es/")	
viewer = Viewer()
viewer.add_dataset(ds)
viewer.show()

# %% [markdown]
# ### Cloud masking

# %%
cloud_mask = np.logical_not(ds["scl"].isin([8, 9, 3]))

ds = ds.where(cloud_mask)

# %% [markdown]
# ### Land masking

# %%
land_mask = ds["scl"] == 6
ds = ds.where(land_mask)

# %% [markdown]
# ### Monthly composite

# %%
monthly_median = ds.groupby("time.month").median().to_dataarray(dim="bands")
monthly_median
# Out:
# <xarray.DataArray (bands: 5, month: 2, y: 3568, x: 3904)> Size: 1GB
# dask.array<stack, shape=(5, 2, 3568, 3904), dtype=float64, chunksize=(1, 1, 1528, 1567), chunktype=numpy.ndarray>
# Coordinates:
#     spatial_ref  int64 8B 0
#   * x            (x) float64 31kB 1.75e+05 1.75e+05 ... 2.14e+05 2.14e+05
#   * y            (y) float64 29kB 4.257e+06 4.257e+06 ... 4.221e+06 4.221e+06
#   * month        (month) int64 16B 4 5
#   * bands        (bands) object 40B 'b02' 'b03' 'b04' 'b01' 'scl'
# Attributes: (4)

# %%
monthly_median = monthly_median.compute()
monthly_median
# Out:
# ---------------------------------------------------------------------------
# ServerDisconnectedError                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 monthly_median = monthly_median.compute()
#       2 monthly_median
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/dataarray.py:1206, in DataArray.compute(self, **kwargs)
#    1181 """Manually trigger loading of this array's data from disk or a
#    1182 remote source into memory and return a new array.
#    1183
#    (...)
#    1203 dask.compute
#    1204 """
#    1205 new = self.copy(deep=False)
# -> 1206 return new.load(**kwargs)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/dataarray.py:1174, in DataArray.load(self, **kwargs)
#    1154 def load(self, **kwargs) -> Self:
#    1155     """Manually trigger loading of this array's data from disk or a
#    1156     remote source into memory and return this array.
#    1157
#    (...)
#    1172     dask.compute
#    1173     """
# -> 1174     ds = self._to_temp_dataset().load(**kwargs)
#    1175     new = self._from_temp_dataset(ds)
#    1176     self._variable = new._variable
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/dataset.py:900, in Dataset.load(self, **kwargs)
#     897 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     899 # evaluate all the chunked arrays simultaneously
# --> 900 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     901     *lazy_data.values(), **kwargs
#     902 )
#     904 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     905     self.variables[k].data = data
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/dask/base.py:685, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     682     expr = expr.optimize()
#     683     keys = list(flatten(expr.__dask_keys__()))
# --> 685     results = schedule(expr, keys, **kwargs)
#     687 return repack(results)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:573, in ImplicitToExplicitIndexingAdapter.__array__(self, dtype, copy)
#     569 def __array__(
#     570     self, dtype: np.typing.DTypeLike = None, /, *, copy: bool | None = None
#     571 ) -> np.ndarray:
#     572     if Version(np.__version__) >= Version("2.0.0"):
# --> 573         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     574     else:
#     575         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:573, in ImplicitToExplicitIndexingAdapter.__array__(self, dtype, copy)
#     569 def __array__(
#     570     self, dtype: np.typing.DTypeLike = None, /, *, copy: bool | None = None
#     571 ) -> np.ndarray:
#     572     if Version(np.__version__) >= Version("2.0.0"):
# --> 573         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     574     else:
#     575         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:578, in ImplicitToExplicitIndexingAdapter.get_duck_array(self)
#     577 def get_duck_array(self):
# --> 578     return self.array.get_duck_array()
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:789, in CopyOnWriteArray.get_duck_array(self)
#     788 def get_duck_array(self):
# --> 789     return self.array.get_duck_array()
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:659, in LazilyIndexedArray.get_duck_array(self)
#     654 # self.array[self.key] is now a numpy array when
#     655 # self.array is a BackendArray subclass
#     656 # and self.key is BasicIndexer((slice(None, None, None),))
#     657 # so we need the explicit check for ExplicitlyIndexed
#     658 if isinstance(array, ExplicitlyIndexed):
# --> 659     array = array.get_duck_array()
#     660 return _wrap_numpy_scalars(array)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/coding/variables.py:81, in _ElementwiseFunctionArray.get_duck_array(self)
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/coding/variables.py:81, in _ElementwiseFunctionArray.get_duck_array(self)
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:652, in LazilyIndexedArray.get_duck_array(self)
#     648     array = apply_indexer(self.array, self.key)
#     649 else:
#     650     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     651     # it may wrap a BackendArray so use its __getitem__
# --> 652     array = self.array[self.key]
#     654 # self.array[self.key] is now a numpy array when
#     655 # self.array is a BackendArray subclass
#     656 # and self.key is BasicIndexer((slice(None, None, None),))
#     657 # so we need the explicit check for ExplicitlyIndexed
#     658 if isinstance(array, ExplicitlyIndexed):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:227, in ZarrArrayWrapper.__getitem__(self, key)
#     225 elif isinstance(key, indexing.OuterIndexer):
#     226     method = self._oindex
# --> 227 return indexing.explicit_indexing_adapter(
#     228     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     229 )
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/core/indexing.py:1013, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     991 """Support explicit indexing by delegating to a raw indexing method.
#     992
#     993 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1010 Indexing result, in the form of a duck numpy-array.
#    1011 """
#    1012 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1013 result = raw_indexing_method(raw_key.tuple)
#    1014 if numpy_indices.tuple:
#    1015     # index the loaded np.ndarray
#    1016     indexable = NumpyIndexingAdapter(result)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/xarray/backends/zarr.py:217, in ZarrArrayWrapper._getitem(self, key)
#     216 def _getitem(self, key):
# --> 217     return self._array[key]
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/core.py:797, in Array.__getitem__(self, selection)
#     795     result = self.vindex[selection]
#     796 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 797     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     798 else:
#     799     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/core.py:1079, in Array.get_orthogonal_selection(self, selection, out, fields)
#    1076 # setup indexer
#    1077 indexer = OrthogonalIndexer(selection, self)
# -> 1079 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/core.py:1342, in Array._get_selection(self, indexer, out, fields)
#    1339 if math.prod(out_shape) > 0:
#    1340     # allow storage to get multiple items at once
#    1341     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1342     self._chunk_getitems(
#    1343         lchunk_coords,
#    1344         lchunk_selection,
#    1345         out,
#    1346         lout_selection,
#    1347         drop_axes=indexer.drop_axes,
#    1348         fields=fields,
#    1349     )
#    1350 if out.shape:
#    1351     return out
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/core.py:2183, in Array._chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection, drop_axes, fields)
#    2181     if not isinstance(self._meta_array, np.ndarray):
#    2182         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2183     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2185 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    2186     if ckey in cdatas:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/zarr/storage.py:1435, in FSStore.getitems(self, keys, contexts)
#    1432     continue
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#    1440     results[keys_transformed[k]] = v
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/asyn.py:244, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     242 async def _run_coro(coro, i):
#     243     try:
# --> 244         return await asyncio.wait_for(coro, timeout=timeout), i
#     245     except Exception as e:
#     246         if not return_exceptions:
#
# File ~/anaconda3/envs/landscape/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/fsspec/implementations/http.py:245, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     243     kw["headers"] = headers
#     244 session = await self.set_session()
# --> 245 async with session.get(self.encode_url(url), **kw) as r:
#     246     out = await r.read()
#     247     self._raise_not_found_for_status(r, url)
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/aiohttp/client.py:1510, in _BaseRequestContextManager.__aenter__(self)
#    1509 async def __aenter__(self) -> _RetType:
# -> 1510     self._resp: _RetType = await self._coro
#    1511     return await self._resp.__aenter__()
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/aiohttp/client.py:779, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     776     handler = _connect_and_send_request
#     778 try:
# --> 779     resp = await handler(req)
#     780 # Client connector errors should not be retried
#     781 except (
#     782     ConnectionTimeoutError,
#     783     ClientConnectorError,
#     784     ClientConnectorCertificateError,
#     785     ClientConnectorSSLError,
#     786 ):
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/aiohttp/client.py:757, in ClientSession._request.<locals>._connect_and_send_request(req)
#     755 resp = await req.send(conn)
#     756 try:
# --> 757     await resp.start(conn)
#     758 except BaseException:
#     759     resp.close()
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/aiohttp/client_reqrep.py:539, in ClientResponse.start(self, connection)
#     537 try:
#     538     protocol = self._protocol
# --> 539     message, payload = await protocol.read()  # type: ignore[union-attr]
#     540 except http.HttpProcessingError as exc:
#     541     raise ClientResponseError(
#     542         self.request_info,
#     543         self.history,
#    (...)
#     546         headers=exc.headers,
#     547     ) from exc
#
# File ~/anaconda3/envs/landscape/lib/python3.13/site-packages/aiohttp/streams.py:680, in DataQueue.read(self)
#     678 self._waiter = self._loop.create_future()
#     679 try:
# --> 680     await self._waiter
#     681 except (asyncio.CancelledError, asyncio.TimeoutError):
#     682     self._waiter = None
#
# ServerDisconnectedError: Server disconnected

# %%
monthly_median.loc[dict(bands=["b04", "b03", "b02"])][:, 0].plot.imshow(vmin=0, vmax=0.25) # change 0 by 1, etc for other months

# %% [markdown]
# ### Median composite

# %%
composite = ds.median(dim="time").to_dataarray(dim="bands")
composite
# Out:
# <xarray.DataArray (bands: 5, y: 3568, x: 3904)> Size: 557MB
# dask.array<stack, shape=(5, 3568, 3904), dtype=float64, chunksize=(1, 1429, 1466), chunktype=numpy.ndarray>
# Coordinates:
#     spatial_ref  int64 8B 0
#   * x            (x) float64 31kB 1.75e+05 1.75e+05 ... 2.14e+05 2.14e+05
#   * y            (y) float64 29kB 4.257e+06 4.257e+06 ... 4.221e+06 4.221e+06
#   * bands        (bands) object 40B 'b02' 'b03' 'b04' 'b01' 'scl'

# %%
composite = composite.compute()
composite
# Out:
# <xarray.DataArray (bands: 5, y: 3568, x: 3904)> Size: 557MB
# array([[[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ..., 0.0425    ,
#          0.03175   , 0.03055   ],
#         [       nan,        nan,        nan, ..., 0.04064175,
#          0.04221513, 0.04064953],
#         ...,
#         [       nan,        nan,        nan, ..., 0.04199094,
#          0.04217997, 0.03805   ],
#         [       nan,        nan,        nan, ..., 0.04161101,
#          0.03914321, 0.03615   ],
#         [       nan,        nan,        nan, ..., 0.03835138,
#          0.03498079, 0.0345    ]],
#
#        [[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ..., 0.0265    ,
#          0.0207    , 0.02025   ],
#         [       nan,        nan,        nan, ..., 0.02874524,
#          0.03011884, 0.02980278],
# ...
#         [       nan,        nan,        nan, ..., 0.04116984,
#          0.04117216, 0.04516563],
#         [       nan,        nan,        nan, ..., 0.04091656,
#          0.04095582, 0.04517188],
#         [       nan,        nan,        nan, ..., 0.04074727,
#          0.04080362, 0.04514375]],
#
#        [[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ..., 6.        ,
#          6.        , 6.        ],
#         [       nan,        nan,        nan, ..., 6.        ,
#          6.        , 6.        ],
#         ...,
#         [       nan,        nan,        nan, ..., 6.        ,
#          6.        , 6.        ],
#         [       nan,        nan,        nan, ..., 6.        ,
#          6.        , 6.        ],
#         [       nan,        nan,        nan, ..., 6.        ,
#          6.        , 6.        ]]])
# Coordinates:
#     spatial_ref  int64 8B 0
#   * x            (x) float64 31kB 1.75e+05 1.75e+05 ... 2.14e+05 2.14e+05
#   * y            (y) float64 29kB 4.257e+06 4.257e+06 ... 4.221e+06 4.221e+06
#   * bands        (bands) object 40B 'b02' 'b03' 'b04' 'b01' 'scl'

# %%
composite.loc[dict(bands=["b04", "b03", "b02"])].plot.imshow(vmin=0, vmax=0.25)

# %% [markdown]
# ### To GeoTiff

# %%
import rioxarray
# Save to GeoTIFF
composite.rio.to_raster("composite.tif")

# %% [markdown]
# ### From here proceed with the analysis as usual
